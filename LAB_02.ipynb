# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Input data (hours studied)
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)

# Output data (exam scores)
y = np.array([40, 50, 60, 70, 80])

# Create and train the model
model = LinearRegression()
model.fit(X, y)

# Make a prediction
hours = 6
predicted_score = model.predict([[hours]])

print("Predicted score for 6 hours of study:", predicted_score[0])

# Plot the results
plt.scatter(X, y, color="blue", label="Actual data")
plt.plot(X, model.predict(X), color="red", label="Regression line")
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.legend()
plt.show()
# Out:
# Predicted score for 6 hours of study: 90.0

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# House size (sq ft)
X = np.array([500, 700, 900, 1100]).reshape(-1, 1)

# House price (in thousands)
y = np.array([150, 200, 250, 300])

model = LinearRegression()
model.fit(X, y)

# Predict price for a 1000 sq ft house
prediction = model.predict([[1000]])

print("Predicted house price:", prediction[0], "thousand dollars")
# Out:
# Predicted house price: 275.0 thousand dollars

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Years of experience
X = np.array([1, 3, 5, 7]).reshape(-1, 1)

# Salary
y = np.array([35000, 50000, 65000, 80000])

model = LinearRegression()
model.fit(X, y)

# Predict salary for 6 years of experience
prediction = model.predict([[6]])

print("Predicted salary:", prediction[0])
# Out:
# Predicted salary: 72500.0

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Advertising spend (in thousands)
X = np.array([5, 10, 15, 20]).reshape(-1, 1)

# Sales (in thousands)
y = np.array([25, 45, 65, 85])

model = LinearRegression()
model.fit(X, y)

# Predict sales for $12k ad spend
prediction = model.predict([[12]])

print("Predicted sales:", prediction[0], "thousand")
# Out:
# Predicted sales: 53.0 thousand

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Hours studied
X = np.array([2, 4, 6]).reshape(-1, 1)

# Marks obtained
y = np.array([53, 71, 89])

model = LinearRegression()
model.fit(X, y)

# Predict marks for 5 hours of study
prediction = model.predict([[5]])

print("Predicted marks:", prediction[0])
# Out:
# Predicted marks: 80.0

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Height in cm
X = np.array([150, 160, 170, 180]).reshape(-1, 1)

# Weight in kg
y = np.array([50, 58, 66, 75])

model = LinearRegression()
model.fit(X, y)

# Predict weight for 175 cm height
prediction = model.predict([[175]])

print("Predicted weight:", prediction[0], "kg")
# Out:
# Predicted weight: 70.54999999999998 kg

# %%
import matplotlib.pyplot as plt

plt.scatter(X, y, color="blue", label="Actual data")
plt.plot(X, model.predict(X), color="red", label="Regression line")
plt.xlabel("Input")
plt.ylabel("Output")
plt.legend()
plt.show()

# %%
import numpy as np

class LinearRegressionModel:
    def __init__(self, learning_rate=0.01, epochs=1000):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.m = 0  # slope
        self.b = 0  # intercept

    def fit(self, X, y):
        n = len(X)

        for _ in range(self.epochs):
            y_pred = self.m * X + self.b

            # Gradients
            dm = (-2/n) * np.sum(X * (y - y_pred))
            db = (-2/n) * np.sum(y - y_pred)

            # Update parameters
            self.m -= self.learning_rate * dm
            self.b -= self.learning_rate * db

    def predict(self, X):
        return self.m * X + self.b

# %%
# Training data
X = np.array([1, 2, 3, 4, 5])
y = np.array([40, 50, 60, 70, 80])

# Create and train model
model = LinearRegressionModel(learning_rate=0.01, epochs=1000)
model.fit(X, y)

# Predictions
predictions = model.predict(X)

print("Slope (m):", model.m)
print("Intercept (b):", model.b)
print("Predictions:", predictions)
# Out:
# Slope (m): 10.236908703469044
# Intercept (b): 29.144684409752198
# Predictions: [39.38159311 49.61850182 59.85541052 70.09231922 80.32922793]
